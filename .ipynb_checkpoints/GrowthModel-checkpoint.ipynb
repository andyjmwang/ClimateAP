# %% [markdown]
# # Pricing Uncertainty Induced by Climate Change
# by Professor [Michael Barnett](https://sites.google.com/site/michaelduglasbarnett/home), Professor [William Brock](https://www.ssc.wisc.edu/~wbrock/) and Professor [Lars Peter Hansen](https://larspeterhansen.org/), you could find the latest draft [here](https://larspeterhansen.org/research/papers/).
#
# ## Overview
#
# This notebook is to provide the source code and explanations on how we solve our climate problem under __growth damage setting__.
#
# The growth damages model setting is solved using the same numerical method as the preference damage model, with a few minor adjustments made to the equations and calculations. First, the expressions for $\Psi^*(x)$ and $\bar{\Psi}(x)$ are now given by
#
# \begin{align*}
#  \Psi^*(x) & = -  \int_{\Theta} V_k(x) \left[ \nabla \Gamma(\beta f) \beta \right] q^*(\theta | x) P(d\theta) \\
#  \bar{\Psi}(x) & = -  \int_{\Theta} V_k(x) \left[ \nabla \Gamma(\beta f) \beta \right] P(d\theta).
# \end{align*}
#
# Second, these integral expressions can be calculated using entirely analytical simplifictions as will be outlined below.
#
# Finally, there are no longer direct contributions to the damage evolution that have integral expressions that need to be numerically calculated and added to the PDEs derived from application of the F-K formula.
#
# With these differences we can apply the analogous approach to the preference damage setting to derive $ecc^*$, $\bar{ecc}$, and $ucc^*$ for the growth damages model setting. As before, after imposing the same finite difference scheme the PDEs are characterized by unconditionally linear equations that we can solve directly by approximately inverting the linear systems using the conjugate gradient method without the use of the false transient or other iterative schemes. These PDEs can also be alternatively be solved using the implicit, finite-difference scheme with the conjugate gradient solver augmented by a false transient where the coefficients are definied as in the preference damage case, appropriately adjusted for the $\mu^*_X[x,a^*(x)]$, $\mu_X[x,a^*(x)]$, $\Psi^*(x)$, and $\bar{\Psi}(x)$ that correspond to the growth damages model.

# %% [markdown]
# ## Preliminary work: Importing required packages, importing parameters setting, defining functions

# %%
# Required packages
import os
import sys
sys.path.append('./src')
from supportfunctions import *
sys.stdout.flush()

# %% [markdown]
# ## Solving HJB for Growth Damage

# %% [markdown]
# In order to solve the HJB corresponding to the planner's problem for the growth damages version of the mode, we use the numerical method as we did for the preference damage model. The only difference comes from the expressions for the coefficients $A(x), B(x), C(x)$, and $D(x)$, which are now given by
#
# \begin{eqnarray}
# A(x) &=& - \delta \\
# B(x) &=& {\widehat \mu}(x)\\
# C(x) &=& {\frac 1 2} \sigma_X(x)'I\sigma_X(x) \\
# D(x) &=& \delta (1 - \kappa) \left( \log \left[ {\alpha}  - {\widehat i}(x)  - {\widehat j} (x)  \right] + k  \right) + \delta \kappa \left[ \log {\widehat e}(x)   +  r \right] + {\frac {\xi_m} 2} {\widehat g}(x) \cdot {\widehat g}(x)   + \xi_p {\widehat {\mathbb I}}(x) \\
# \end{eqnarray}
#
# where $D(x)$ no longer contains the climate damage impact, but instead ${\widehat \mu}(x)$ incorporates climate damages through their impact on the drift of capital.

# %%
# Loading Smart guesses
guess = pickle.load(open('./data/GrowthAverseguess.pickle', "rb", -1))
v0_guess = guess['v0']
q_guess = guess['q']
e_guess = guess['e']

# %%
start_time = time.time()

ξₚ =  1 / 175  # Ambiguity Averse Paramter 

McD = np.loadtxt('./data/TCRE_MacDougallEtAl2017_update.txt')
par_lambda_McD = McD / 1000

β𝘧 = np.mean(par_lambda_McD)  # Climate sensitivity parameter, MacDougall (2017)
σᵦ = np.var(par_lambda_McD, ddof=1)  # Varaiance of climate sensitivity parameters
λ = 1.0 / σᵦ 

# Parameters are defined the same as they are in the paper
δ = 0.01        
κ = 0.032       
σ𝘨 = 0.02
σ𝘬 = 0.0161
σ𝘳 = 0.0339 
α = 0.115000000000000
ϕ0 = 0.0600
ϕ1 = 16.666666666666668
μ̄ₖ = -0.034977443912449
ψ0 = 0.112733407891680
ψ1 = 0.142857142857143
F̄ = 13

# False trasient time step
ε = 0.1
# Specifying tolerance level
tol = 1e-16
# Cobweb learning rate
η = 0.05

# Solving HJB
R_min = 0
R_max = 9
F_min = 0
F_max = 750
K_min = 0
K_max = 18


# nR = 30
# nF = 30
# nK = 25

# R = np.linspace(R_min, R_max, nR)
# F = np.linspace(F_min, F_max, nF)
# K = np.linspace(K_min, K_max, nK)

# hR = R[1] - R[0]
# hF = F[1] - F[0]
# hK = K[1] - K[0]

hR = 0.05
hF = 25
hK = 0.15

R = np.arange(R_min, R_max + hR, hR)
nR = len(R)
F = np.arange(F_min, F_max + hF, hF)
nF = len(F)
K = np.arange(K_min, K_max + hK, hK)
nK = len(K)


# Here's how we discretize our state space formulating PDE, see Remark 2 in Preference setting
(R_mat, F_mat, K_mat) = np.meshgrid(R,F,K, indexing = 'ij')
stateSpace = np.hstack([R_mat.reshape(-1,1,order = 'F'),F_mat.reshape(-1,1,order = 'F'),K_mat.reshape(-1,1,order = 'F')])


μ1 = 1.272e-02
μ2 = -4.871e-04
σ1 = 3.248e-03
σ2 = 1.029e-04
ρ12 = -2.859133e-07

σ2 = σ2 * 2
ρ12 = ρ12 * 2

μ = np.matrix([-μ1, -μ2 * 2])
σ = np.matrix([[σ1 ** 2, ρ12], [ρ12, σ2 ** 2]])
Σ = np.matrix([[σᵦ,0,0],[0,σ1 ** 2, ρ12],[0, ρ12, σ2 ** 2]])

[gam1,w1] = quad_points_hermite(3)
gamm1 = np.sqrt(2) * 1 * gam1 + 0
[gam2,w2] = quad_points_hermite(3)
gamm2 = np.sqrt(2) * 1 * gam2 + 0

At = np.linalg.cholesky(σ)
x = np.zeros([2,9])
tmp = [-μ1,-μ2 * 2]
x[:,0] = tmp + At.dot([gamm1[0], gamm2[0]])
x[:,1] = tmp + At.dot([gamm1[0], gamm2[1]])
x[:,2] = tmp + At.dot([gamm1[0], gamm2[2]])
x[:,3] = tmp + At.dot([gamm1[1], gamm2[0]])
x[:,4] = tmp + At.dot([gamm1[1], gamm2[1]])
x[:,5] = tmp + At.dot([gamm1[1], gamm2[2]])
x[:,6] = tmp + At.dot([gamm1[2], gamm2[0]])
x[:,7] = tmp + At.dot([gamm1[2], gamm2[1]])
x[:,8] = tmp + At.dot([gamm1[2], gamm2[2]])

w = np.array([[w1[0],w1[0],w1[0],w1[1],w1[1],w1[1],w1[2],w1[2],w1[2]],
               [w2[0],w2[1],w2[2],w2[0],w2[1],w2[2],w2[0],w2[1],w2[2]]])
gamma1 = x[0,:]
gamma2 = x[1,:]
wgt1 = w[0,:]
wgt2 = w[1,:]

vals = np.linspace(0,30,100)

# dee = np.matrix([-μ1 + -μ2 * 2, β𝘧, β𝘧])
# σ𝘥 = float(np.sqrt(dee * Σ * dee.T))

weight = np.zeros(9)
total_weight = 0
for ite in range(9):
    weight[ite] = wgt1[ite] * wgt2[ite]
    total_weight += weight[ite]
    
weight = weight / total_weight

gamma0 = np.zeros(9)
for ite in range(9):
    gamma0[ite] = max(-(gamma1[ite] * vals + 0.5 * gamma2[ite] * vals ** 2))
    
v0 = κ * R_mat + (1-κ) * K_mat

episode = 1
FC_Err = 1
v0 = v0_guess
q = q_guess
e_star = e_guess

# while episode == 0 or np.max(abs((out_comp - vold))) > tol:
while episode <= 200:# or FC_Err > tol:
    vold = v0.copy()
    # Applying finite difference scheme to the value function
    v0_dr = finiteDiff(v0,0,1,hR) 
    v0_df = finiteDiff(v0,1,1,hF)
    v0_dk = finiteDiff(v0,2,1,hK)

    v0_drr = finiteDiff(v0,0,2,hR)
    v0_drr[v0_dr < 1e-16] = 0
    v0_dr[v0_dr < 1e-16] = 1e-16
    v0_dff = finiteDiff(v0,1,2,hF)
    v0_dkk = finiteDiff(v0,2,2,hK)
    
    if episode == 0:
        # First time into the loop
#         B1 = v0_dr - v0_df * np.exp(R_mat)
#         C1 = δ * κ
#         e = C1 / B1
#         e_hat = e
#         e_star = e_hat

#         Acoeff = np.exp(R_mat - K_mat)
#         Bcoeff = δ * (1-κ) / (np.exp(-R_mat + K_mat) * v0_dr * ψ0 * 0.5) + v0_dk * ϕ0 / (np.exp(-R_mat + K_mat) * v0_dr * ψ0 * 0.5)
        Acoeff = np.ones(R_mat.shape)
        Bcoeff = ((δ * (1 - κ) * ϕ1 + ϕ0 * ϕ1 * v0_dk) * δ * (1 - κ) / (v0_dr * ψ0 * 0.5) * np.exp(0.5 * (R_mat - K_mat))) / (δ * (1 - κ) * ϕ1)
        Ccoeff = -α  - 1 / ϕ1
        j = ((-Bcoeff + np.sqrt(Bcoeff ** 2 - 4 * Acoeff * Ccoeff)) / (2 * Acoeff)) ** 2
#         i = (v0_dk * ϕ0 /(np.exp(-R_mat + K_mat) * v0_dr * ψ0 * 0.5)) * (j ** 0.5) - 1 / ϕ1
        i = α - j - (δ * (1 - κ)) / (v0_dr * ψ0 * 0.5) * j ** 0.5 * np.exp(0.5 * (R_mat - K_mat))
        q = δ * (1 - κ) / (α - i - j)        
    else:
#         e_hat = e_star
#         j  = ((α + 1 / ϕ1) * np.exp(-R_mat + K_mat) * (v0_dr * ψ0 * ψ1)/((v0_dr * ψ0 * ψ1) * j ** ψ1 + (δ * (1-κ) + v0_dk * ϕ0))) ** (1/(1-ψ1))
#         j = j * (v0_dr > 1e-8)
#         i = ((v0_dk * ϕ0 / (np.exp(-R_mat + K_mat) * v0_dr * ψ0 * ψ1)) * (j ** (1 - ψ1)) - 1 / ϕ1) * (v0_dr > 1e-8) + (v0_dr <= 1e-8) * (v0_dk * ϕ0 * α - δ * (1-κ) / ϕ1) / (δ * (1-κ) + v0_dk * ϕ0)
        
        # Cobeweb scheme to update i and j; q is an intermediary variable that determines i and j
        Converged = 0
        nums = 0
        while Converged == 0:
            i_star = (ϕ0 * ϕ1 * v0_dk / q - 1) / ϕ1
            j_star = (q * np.exp(ψ1 * (R_mat - K_mat)) / (v0_dr * ψ0 * ψ1)) ** (1 / (ψ1 - 1))
            if α > np.max(i_star + j_star):
                q_star = η * δ * (1 - κ) / (α - i_star - j_star) + (1 - η) * q
            else:
                q_star = 2 * q
            if np.max(abs(q - q_star) / η) <= 1e-5:
                Converged = 1
                q = q_star
                i = i_star
                j = j_star
            else:
                q = q_star
                i = i_star
                j = j_star
            
            nums += 1
        print('Cobweb Passed, iterations: {}, i error: {:10f}, j error: {:10f}'.format(nums, np.max(i - i_star), np.max(j - j_star)))
        

    a_ = [] 
    b_ = [] 
    c_ = [] 
    λ̃_ = [] 
    β̃_ = [] 
    I_ = [] 
    R_ = [] 
    π̃_ = [] 
    J_ = []

    for ite in range(9):
        a_.append( -v0_dk * (gamma0[ite] + gamma1[ite] * F̄ + 0.5 * gamma2[ite] * F̄ ** 2) )
        b_.append( -v0_dk * F_mat * (gamma1[ite] + gamma2[ite] * F̄) )
        c_.append( -v0_dk * gamma2[ite] * F_mat ** 2 )
        λ̃_.append( λ + c_[ite] / ξₚ )
        β̃_.append( β𝘧 - c_[ite] / ξₚ / λ̃_[ite] * β𝘧 - b_[ite] / (ξₚ * λ̃_[ite]))
        I_.append( a_[ite] - 0.5 * np.log(λ) * ξₚ + 0.5 * np.log(λ̃_[ite]) * ξₚ + 0.5 * λ * β𝘧 ** 2 * ξₚ - 0.5 * λ̃_[ite] * (β̃_[ite]) ** 2 * ξₚ )
    # seems redundant   R_.append( / ξₚ * (I_[ite] - (a_[ite] + b_[ite] * β̃_[ite] + c_[ite] * β̃_[ite] ** 2 + c_[ite] / λ̃_[ite])) )
        π̃_.append( weight[ite] * np.exp(-1 / ξₚ * I_[ite]) )
        J_.append( a_[ite] + b_[ite] * β̃_[ite] + 0.5 * c_[ite] * β̃_[ite] ** 2 + 0.5 * c_[ite] / λ̃_[ite] )
        R_.append((I_[ite] - J_[ite]) / ξₚ)


    π̃_total = sum(π̃_)
    π̃_norm_ = π̃_ / π̃_total

    B1 = v0_dr - v0_df * np.exp(R_mat)
    C1 = δ * κ
    e = C1 / B1
    e_star = e

    I_term = -1 * ξₚ * np.log(sum(π̃_))
    drift_distort = sum([x*y for (x,y) in zip(π̃_norm_, J_)])
    RE = sum(x * y + x * np.log(x / z) for (x,y,z) in zip(π̃_norm_, R_, weight))
    RE_total = ξₚ * RE

    # Step (6) and (7) Formulating coefficients for the linear system, See remark 4 for more details
    A = -δ * np.ones(R_mat.shape)
#     B_r = -e_star + ψ0 * (j ** ψ1) - 0.5 * (σ𝘳 ** 2)
    B_r = -e_star + ψ0 * (j ** ψ1) * np.exp(ψ1 * (K_mat - R_mat)) - 0.5 * (σ𝘳 ** 2)
    B_k = μ̄ₖ + ϕ0 * np.log(1 + i * ϕ1) - 0.5 * (σ𝘬 ** 2)
    B_f = e_star * np.exp(R_mat)
    C_rr = 0.5 * σ𝘳 ** 2 * np.ones(R_mat.shape)
    C_kk = 0.5 * σ𝘬 ** 2 * np.ones(R_mat.shape)
    C_ff = np.zeros(R_mat.shape)

#     D = δ * κ * np.log(e_star) + δ * κ * R_mat + δ * (1 - κ) * (np.log(α - i - j * np.exp(R_mat - K_mat)) + K_mat) + I_term #  + drift_distort + RE_total
    D = δ * κ * np.log(e_star) + δ * κ * R_mat + δ * (1 - κ) * (np.log(α - i - j) + K_mat) + I_term #  + drift_distort + RE_total
    
    # Solve linear system using a conjugate-gradient method in C++, see remark 5, 6 for more details
    out = PDESolver(stateSpace, A, B_r, B_f, B_k, C_rr, C_ff, C_kk, D, v0, ε, 'False Transient')

    out_comp = out[2].reshape(v0.shape,order = "F")
    
    # Calculating PDE Error and False Transient (lhs) Error
    PDE_rhs = A * v0 + B_r * v0_dr + B_f * v0_df + B_k * v0_dk + C_rr * v0_drr + C_kk * v0_dkk + C_ff * v0_dff + D
    PDE_Err = np.max(abs(PDE_rhs))
    FC_Err = np.max(abs((out_comp - v0)))
    if episode % 100 == 0:
        print("Episode {:d}: PDE Error: {:.10f}; False Transient Error: {:.10f}; Iterations: {:d}; CG Error: {:.10f}" .format(episode, PDE_Err, FC_Err, out[0], out[1]))
    episode += 1
    v0 = out_comp

print("Episode {:d}: PDE Error: {:.10f}; False Transient Error: {:.10f}; Iterations: {:d}; CG Error: {:.10f}" .format(episode, PDE_Err, FC_Err, out[0], out[1]))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 1: PDE Error: 0.0000155068; False Transient Error: 0.0000000100; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 2: PDE Error: 0.0000155069; False Transient Error: 0.0000000100; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 3: PDE Error: 0.0000155069; False Transient Error: 0.0000000100; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 4: PDE Error: 0.0000155069; False Transient Error: 0.0000000100; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 5: PDE Error: 0.0000155070; False Transient Error: 0.0000000099; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 6: PDE Error: 0.0000155070; False Transient Error: 0.0000000099; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 7: PDE Error: 0.0000155070; False Transient Error: 0.0000000099; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 8: PDE Error: 0.0000155071; False Transient Error: 0.0000000099; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 9: PDE Error: 0.0000155071; False Transient Error: 0.0000000099; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 10: PDE Error: 0.0000155071; False Transient Error: 0.0000000099; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 11: PDE Error: 0.0000155072; False Transient Error: 0.0000000099; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 12: PDE Error: 0.0000155072; False Transient Error: 0.0000000099; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 13: PDE Error: 0.0000155072; False Transient Error: 0.0000000099; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 14: PDE Error: 0.0000155073; False Transient Error: 0.0000000098; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 15: PDE Error: 0.0000155073; False Transient Error: 0.0000000098; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 16: PDE Error: 0.0000155073; False Transient Error: 0.0000000098; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 17: PDE Error: 0.0000155074; False Transient Error: 0.0000000098; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 18: PDE Error: 0.0000155074; False Transient Error: 0.0000000098; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 19: PDE Error: 0.0000155074; False Transient Error: 0.0000000098; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 20: PDE Error: 0.0000155075; False Transient Error: 0.0000000098; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 21: PDE Error: 0.0000155075; False Transient Error: 0.0000000097; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 22: PDE Error: 0.0000155075; False Transient Error: 0.0000000097; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 23: PDE Error: 0.0000155076; False Transient Error: 0.0000000097; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 24: PDE Error: 0.0000155076; False Transient Error: 0.0000000097; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 25: PDE Error: 0.0000155076; False Transient Error: 0.0000000097; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 26: PDE Error: 0.0000155077; False Transient Error: 0.0000000097; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 27: PDE Error: 0.0000155077; False Transient Error: 0.0000000097; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 28: PDE Error: 0.0000155078; False Transient Error: 0.0000000097; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 29: PDE Error: 0.0000155078; False Transient Error: 0.0000000097; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 30: PDE Error: 0.0000155078; False Transient Error: 0.0000000097; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 31: PDE Error: 0.0000155079; False Transient Error: 0.0000000097; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 32: PDE Error: 0.0000155079; False Transient Error: 0.0000000097; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 33: PDE Error: 0.0000155079; False Transient Error: 0.0000000097; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 34: PDE Error: 0.0000155080; False Transient Error: 0.0000000096; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 35: PDE Error: 0.0000155080; False Transient Error: 0.0000000096; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 36: PDE Error: 0.0000155080; False Transient Error: 0.0000000096; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 37: PDE Error: 0.0000155081; False Transient Error: 0.0000000096; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 38: PDE Error: 0.0000155081; False Transient Error: 0.0000000096; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 39: PDE Error: 0.0000155081; False Transient Error: 0.0000000096; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 40: PDE Error: 0.0000155082; False Transient Error: 0.0000000096; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 41: PDE Error: 0.0000155082; False Transient Error: 0.0000000096; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 42: PDE Error: 0.0000155082; False Transient Error: 0.0000000096; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 43: PDE Error: 0.0000155083; False Transient Error: 0.0000000096; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 44: PDE Error: 0.0000155083; False Transient Error: 0.0000000096; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 45: PDE Error: 0.0000155083; False Transient Error: 0.0000000096; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 46: PDE Error: 0.0000155084; False Transient Error: 0.0000000096; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 47: PDE Error: 0.0000155084; False Transient Error: 0.0000000096; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 48: PDE Error: 0.0000155084; False Transient Error: 0.0000000096; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 49: PDE Error: 0.0000155085; False Transient Error: 0.0000000096; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 50: PDE Error: 0.0000155085; False Transient Error: 0.0000000095; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 51: PDE Error: 0.0000155085; False Transient Error: 0.0000000095; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 52: PDE Error: 0.0000155086; False Transient Error: 0.0000000095; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 53: PDE Error: 0.0000155086; False Transient Error: 0.0000000095; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 54: PDE Error: 0.0000155086; False Transient Error: 0.0000000095; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 55: PDE Error: 0.0000155087; False Transient Error: 0.0000000095; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 56: PDE Error: 0.0000155087; False Transient Error: 0.0000000095; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 57: PDE Error: 0.0000155087; False Transient Error: 0.0000000095; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 58: PDE Error: 0.0000155088; False Transient Error: 0.0000000095; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 59: PDE Error: 0.0000155088; False Transient Error: 0.0000000095; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 60: PDE Error: 0.0000155088; False Transient Error: 0.0000000095; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 61: PDE Error: 0.0000155089; False Transient Error: 0.0000000095; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 62: PDE Error: 0.0000155089; False Transient Error: 0.0000000095; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 63: PDE Error: 0.0000155089; False Transient Error: 0.0000000095; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 64: PDE Error: 0.0000155090; False Transient Error: 0.0000000094; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 65: PDE Error: 0.0000155090; False Transient Error: 0.0000000094; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 66: PDE Error: 0.0000155090; False Transient Error: 0.0000000094; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 67: PDE Error: 0.0000155090; False Transient Error: 0.0000000094; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 68: PDE Error: 0.0000155091; False Transient Error: 0.0000000094; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 69: PDE Error: 0.0000155091; False Transient Error: 0.0000000094; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 70: PDE Error: 0.0000155091; False Transient Error: 0.0000000094; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 71: PDE Error: 0.0000155092; False Transient Error: 0.0000000094; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 72: PDE Error: 0.0000155092; False Transient Error: 0.0000000094; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 73: PDE Error: 0.0000155092; False Transient Error: 0.0000000094; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 74: PDE Error: 0.0000155093; False Transient Error: 0.0000000094; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 75: PDE Error: 0.0000155093; False Transient Error: 0.0000000094; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 76: PDE Error: 0.0000155093; False Transient Error: 0.0000000093; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 77: PDE Error: 0.0000155094; False Transient Error: 0.0000000093; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 78: PDE Error: 0.0000155094; False Transient Error: 0.0000000093; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 79: PDE Error: 0.0000155094; False Transient Error: 0.0000000093; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 80: PDE Error: 0.0000155095; False Transient Error: 0.0000000093; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 81: PDE Error: 0.0000155095; False Transient Error: 0.0000000093; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 82: PDE Error: 0.0000155095; False Transient Error: 0.0000000093; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 83: PDE Error: 0.0000155096; False Transient Error: 0.0000000093; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 84: PDE Error: 0.0000155096; False Transient Error: 0.0000000093; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 85: PDE Error: 0.0000155096; False Transient Error: 0.0000000093; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 86: PDE Error: 0.0000155097; False Transient Error: 0.0000000093; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 87: PDE Error: 0.0000155097; False Transient Error: 0.0000000093; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 88: PDE Error: 0.0000155097; False Transient Error: 0.0000000092; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 89: PDE Error: 0.0000155098; False Transient Error: 0.0000000092; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 90: PDE Error: 0.0000155098; False Transient Error: 0.0000000092; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 91: PDE Error: 0.0000155098; False Transient Error: 0.0000000092; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 92: PDE Error: 0.0000155099; False Transient Error: 0.0000000092; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 93: PDE Error: 0.0000155099; False Transient Error: 0.0000000092; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 94: PDE Error: 0.0000155099; False Transient Error: 0.0000000092; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 95: PDE Error: 0.0000155100; False Transient Error: 0.0000000092; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 96: PDE Error: 0.0000155100; False Transient Error: 0.0000000092; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 97: PDE Error: 0.0000155100; False Transient Error: 0.0000000092; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 98: PDE Error: 0.0000155100; False Transient Error: 0.0000000092; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 99: PDE Error: 0.0000155101; False Transient Error: 0.0000000092; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 100: PDE Error: 0.0000155101; False Transient Error: 0.0000000091; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 101: PDE Error: 0.0000155101; False Transient Error: 0.0000000091; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 102: PDE Error: 0.0000155102; False Transient Error: 0.0000000091; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 103: PDE Error: 0.0000155102; False Transient Error: 0.0000000091; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 104: PDE Error: 0.0000155102; False Transient Error: 0.0000000091; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 105: PDE Error: 0.0000155103; False Transient Error: 0.0000000091; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 106: PDE Error: 0.0000155103; False Transient Error: 0.0000000091; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 107: PDE Error: 0.0000155103; False Transient Error: 0.0000000091; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 108: PDE Error: 0.0000155104; False Transient Error: 0.0000000091; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 109: PDE Error: 0.0000155104; False Transient Error: 0.0000000091; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 110: PDE Error: 0.0000155104; False Transient Error: 0.0000000091; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 111: PDE Error: 0.0000155105; False Transient Error: 0.0000000091; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 112: PDE Error: 0.0000155105; False Transient Error: 0.0000000091; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 113: PDE Error: 0.0000155105; False Transient Error: 0.0000000091; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 114: PDE Error: 0.0000155105; False Transient Error: 0.0000000091; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 115: PDE Error: 0.0000155106; False Transient Error: 0.0000000090; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 116: PDE Error: 0.0000155106; False Transient Error: 0.0000000090; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 117: PDE Error: 0.0000155106; False Transient Error: 0.0000000090; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 118: PDE Error: 0.0000155107; False Transient Error: 0.0000000090; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 119: PDE Error: 0.0000155107; False Transient Error: 0.0000000090; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 120: PDE Error: 0.0000155107; False Transient Error: 0.0000000090; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 121: PDE Error: 0.0000155108; False Transient Error: 0.0000000090; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 122: PDE Error: 0.0000155108; False Transient Error: 0.0000000090; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 123: PDE Error: 0.0000155108; False Transient Error: 0.0000000090; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 124: PDE Error: 0.0000155109; False Transient Error: 0.0000000090; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 125: PDE Error: 0.0000155109; False Transient Error: 0.0000000090; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 126: PDE Error: 0.0000155109; False Transient Error: 0.0000000090; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 127: PDE Error: 0.0000155110; False Transient Error: 0.0000000089; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 128: PDE Error: 0.0000155110; False Transient Error: 0.0000000089; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 129: PDE Error: 0.0000155110; False Transient Error: 0.0000000089; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 130: PDE Error: 0.0000155110; False Transient Error: 0.0000000089; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 131: PDE Error: 0.0000155111; False Transient Error: 0.0000000090; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 132: PDE Error: 0.0000155111; False Transient Error: 0.0000000089; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 133: PDE Error: 0.0000155111; False Transient Error: 0.0000000089; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 134: PDE Error: 0.0000155112; False Transient Error: 0.0000000089; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 135: PDE Error: 0.0000155112; False Transient Error: 0.0000000089; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 136: PDE Error: 0.0000155112; False Transient Error: 0.0000000089; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 137: PDE Error: 0.0000155113; False Transient Error: 0.0000000089; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 138: PDE Error: 0.0000155113; False Transient Error: 0.0000000089; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 139: PDE Error: 0.0000155113; False Transient Error: 0.0000000089; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 140: PDE Error: 0.0000155113; False Transient Error: 0.0000000089; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 141: PDE Error: 0.0000155114; False Transient Error: 0.0000000089; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 142: PDE Error: 0.0000155114; False Transient Error: 0.0000000089; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 143: PDE Error: 0.0000155114; False Transient Error: 0.0000000088; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 144: PDE Error: 0.0000155115; False Transient Error: 0.0000000088; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 145: PDE Error: 0.0000155115; False Transient Error: 0.0000000088; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 146: PDE Error: 0.0000155115; False Transient Error: 0.0000000088; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 147: PDE Error: 0.0000155116; False Transient Error: 0.0000000088; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 148: PDE Error: 0.0000155116; False Transient Error: 0.0000000088; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 149: PDE Error: 0.0000155116; False Transient Error: 0.0000000088; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 150: PDE Error: 0.0000155117; False Transient Error: 0.0000000088; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 151: PDE Error: 0.0000155117; False Transient Error: 0.0000000088; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 152: PDE Error: 0.0000155117; False Transient Error: 0.0000000088; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 153: PDE Error: 0.0000155117; False Transient Error: 0.0000000088; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 154: PDE Error: 0.0000155118; False Transient Error: 0.0000000088; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 155: PDE Error: 0.0000155118; False Transient Error: 0.0000000088; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 156: PDE Error: 0.0000155118; False Transient Error: 0.0000000088; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 157: PDE Error: 0.0000155119; False Transient Error: 0.0000000088; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 158: PDE Error: 0.0000155119; False Transient Error: 0.0000000087; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 159: PDE Error: 0.0000155119; False Transient Error: 0.0000000087; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 160: PDE Error: 0.0000155120; False Transient Error: 0.0000000087; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 161: PDE Error: 0.0000155120; False Transient Error: 0.0000000087; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 162: PDE Error: 0.0000155120; False Transient Error: 0.0000000087; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 163: PDE Error: 0.0000155120; False Transient Error: 0.0000000087; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 164: PDE Error: 0.0000155121; False Transient Error: 0.0000000087; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 165: PDE Error: 0.0000155121; False Transient Error: 0.0000000087; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 166: PDE Error: 0.0000155121; False Transient Error: 0.0000000087; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 167: PDE Error: 0.0000155122; False Transient Error: 0.0000000087; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 168: PDE Error: 0.0000155122; False Transient Error: 0.0000000087; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 169: PDE Error: 0.0000155122; False Transient Error: 0.0000000087; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 170: PDE Error: 0.0000155122; False Transient Error: 0.0000000087; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 171: PDE Error: 0.0000155123; False Transient Error: 0.0000000087; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 172: PDE Error: 0.0000155123; False Transient Error: 0.0000000086; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 173: PDE Error: 0.0000155123; False Transient Error: 0.0000000086; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 174: PDE Error: 0.0000155124; False Transient Error: 0.0000000086; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 175: PDE Error: 0.0000155124; False Transient Error: 0.0000000086; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 176: PDE Error: 0.0000155124; False Transient Error: 0.0000000086; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 177: PDE Error: 0.0000155125; False Transient Error: 0.0000000086; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 178: PDE Error: 0.0000155125; False Transient Error: 0.0000000086; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 179: PDE Error: 0.0000155125; False Transient Error: 0.0000000086; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 180: PDE Error: 0.0000155125; False Transient Error: 0.0000000086; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 181: PDE Error: 0.0000155126; False Transient Error: 0.0000000086; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 182: PDE Error: 0.0000155126; False Transient Error: 0.0000000086; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 183: PDE Error: 0.0000155126; False Transient Error: 0.0000000086; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 184: PDE Error: 0.0000155127; False Transient Error: 0.0000000086; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 185: PDE Error: 0.0000155127; False Transient Error: 0.0000000085; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 186: PDE Error: 0.0000155127; False Transient Error: 0.0000000085; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 187: PDE Error: 0.0000155127; False Transient Error: 0.0000000085; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 188: PDE Error: 0.0000155128; False Transient Error: 0.0000000085; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 189: PDE Error: 0.0000155128; False Transient Error: 0.0000000085; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 190: PDE Error: 0.0000155128; False Transient Error: 0.0000000085; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 191: PDE Error: 0.0000155129; False Transient Error: 0.0000000085; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 192: PDE Error: 0.0000155129; False Transient Error: 0.0000000085; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 193: PDE Error: 0.0000155129; False Transient Error: 0.0000000085; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 194: PDE Error: 0.0000155129; False Transient Error: 0.0000000085; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 195: PDE Error: 0.0000155130; False Transient Error: 0.0000000085; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 196: PDE Error: 0.0000155130; False Transient Error: 0.0000000085; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 197: PDE Error: 0.0000155130; False Transient Error: 0.0000000085; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 198: PDE Error: 0.0000155131; False Transient Error: 0.0000000084; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 199: PDE Error: 0.0000155131; False Transient Error: 0.0000000084; Iterations: 2; CG Error: 0.0000000001
# Cobweb Passed, iterations: 1, i error:   0.000000, j error:   0.000000
# Episode 200: PDE Error: 0.0000155131; False Transient Error: 0.0000000084; Iterations: 2; CG Error: 0.0000000001
# Episode 201: PDE Error: 0.0000155131; False Transient Error: 0.0000000084; Iterations: 2; CG Error: 0.0000000001
# --- 217.81434607505798 seconds ---

# %% [markdown]
# ### Simulation

# %%
class GridInterp():

    def __init__(self, grids, values, method = 'Linear'):

        # unpacking
        self.grids = grids
        (self.xs, self.ys, self.zs) = grids
        self.nx = len(self.xs)
        self.ny = len(self.ys)
        self.nz = len(self.zs)
        
        self.values = values

        assert (self.nx, self.ny, self.nz) == values.shape, "ValueError: Dimensions not match"
        self.method = method

    def get_value(self, x, y, z):

        if self.method == 'Linear':
            
            func = RegularGridInterpolator(self.grids, self.values)
            return func([x,y,z])[0]

        elif self.method == 'Spline':

            func1 = CubicSpline(self.xs, self.values)
            yzSpace = func1(x)
            
            func2 = CubicSpline(self.ys, yzSpace)
            zSpace = func2(y)
            
            func3 = CubicSpline(self.zs, zSpace)
            return func3(z)

        else:
            raise ValueError('Method Not Supported')

# %%
method = 'Linear'
T = 100
pers = 4 * T
dt = T / pers
nDims = 4
its = 1

gridpoints = (R, F, K)

e_func_r = GridInterp(gridpoints, e, method)
def e_func(x):
    return e_func_r.get_value(np.log(x[0]), x[2], np.log(x[1]))

j_func_r = GridInterp(gridpoints, j, method)
def j_func(x):
    return max(j_func_r.get_value(np.log(x[0]), x[2], np.log(x[1])), 0)

i_func_r = GridInterp(gridpoints, i, method)
def i_func(x):
    return i_func_r.get_value(np.log(x[0]), x[2], np.log(x[1]))

v_drfunc_r = GridInterp(gridpoints, v0_dr, method)
def v_drfunc(x):
    return v_drfunc_r.get_value(np.log(x[0]), x[2], np.log(x[1]))

v_dtfunc_r = GridInterp(gridpoints, v0_df, method)
def v_dtfunc(x):
    return v_dtfunc_r.get_value(np.log(x[0]), x[2], np.log(x[1]))

v_dkfunc_r = GridInterp(gridpoints, v0_dk, method)
def v_dkfunc(x):
    return v_dkfunc_r.get_value(np.log(x[0]), x[2], np.log(x[1]))

v_func_r = GridInterp(gridpoints, v0, method)
def v_func(x):
    return v_func_r.get_value(np.log(x[0]), x[2], np.log(x[1]))

π̃_norm_func = []
π̃_norm_func_r = []

for ite in range(len(π̃_norm_)):
    π̃_norm_func_r.append(GridInterp(gridpoints, π̃_norm_[ite], method))
    π̃_norm_func.append(lambda x, ite = ite: π̃_norm_func_r[ite].get_value(np.log(x[0]), x[2], np.log(x[1])))
#     del tempFunc
#     print("{}, {}".format(ite, π̃_norm_func[ite](hist[0,:])))
#     del ite
# print("{}, {}".format(0, π̃_norm_func[0](hist[0,:])))

RE_func_r = GridInterp(gridpoints, RE, method)
def RE_func(x):
    return RE_func_r.get_value(np.log(x[0]), x[2], np.log(x[1]))

a = []
b = []
c = []
dmg_tilt_ = []
dmg_ = []
base_driftK_r = []
base_driftK = []
tilt_driftK_r = []
tilt_driftK = []

for ite in range(len(π̃_norm_)):
    a.append(gamma0[ite] + gamma1[ite] * F̄ + 0.5 * gamma2[ite] * F̄ ** 2)
    b.append(F_mat * (gamma1[ite] + gamma2[ite] * F̄))
    c.append(gamma2[ite] * F_mat ** 2)
    dmg_tilt_.append(a[ite] + b[ite] * β̃_[ite] + 0.5 * c[ite] * 
                     (β̃_[ite] ** 2) + 0.5 * c[ite] / λ̃_[ite])
    dmg_.append(a[ite] + b[ite] * βf + 0.5 * c[ite] * βf ** 2 + 0.5 * c[ite] / λ)
    base_driftK_r.append(GridInterp(gridpoints, dmg_[ite], method))
    base_driftK.append(lambda x, ite = ite: base_driftK_r[ite].get_value(np.log(x[0]), x[2], np.log(x[1])))
    tilt_driftK_r.append(GridInterp(gridpoints, dmg_tilt_[ite], method))
    tilt_driftK.append(lambda x, ite = ite: tilt_driftK_r[ite].get_value(np.log(x[0]), x[2], np.log(x[1])))
    
def Gamma_base(x):
    res = 0
    for ite in range(len(weight)):
        res += weight[ite] * base_driftK[ite](x)
    return res

def Gamma_tilted(x):
    res = 0
    for ite in range(len(weight)):
        res += π̃_norm_func[ite](x) * tilt_driftK[ite](x)
    return res

def muR(x):
#     return -e_func(x) + ψ0 * j_func(x) ** ψ1
    return -e_func(x) + ψ0 * (j_func(x) * x[1] / x[0]) ** ψ1
def muK_tilted(x): 
    return (μ̄k + ϕ0 * np.log(1 + i_func(x) * ϕ1)- Gamma_tilted(x))
def muK_base(x): 
    return (μ̄k + ϕ0 * np.log(1 + i_func(x) * ϕ1)- Gamma_base(x))
def muF(x):
    return e_func(x) * x[0]

def sigmaR(x):
    return np.zeros(x[:4].shape)
def sigmaK(x):
    return np.zeros(x[:4].shape)
def sigmaF(x):
    return np.zeros(x[:4].shape)

# initial points
R_0 = 650
K_0 = 80 / α
F_0 = 870 - 580
initial_val = np.array([R_0, K_0, F_0])

# Set bounds
R_max_sim = np.exp(max(R))
K_max_sim = np.exp(max(K))
F_max_sim = max(F)

R_min_sim = np.exp(min(R))
K_min_sim = np.exp(min(K))
F_min_sim = min(F)

upperbounds = np.array([R_max_sim, K_max_sim, F_max_sim, K_max_sim])
lowerbounds = np.array([R_min_sim, K_min_sim, F_min_sim, K_min_sim])

hists = np.zeros([pers, nDims, its])
e_hists = np.zeros([pers,its])
j_hists = np.zeros([pers,its])
i_hists = np.zeros([pers,its])
RE_hists = np.zeros([pers,its])

pi_tilde_hists = []
for ite in range(len(π̃_norm_)):
    pi_tilde_hists.append(np.zeros([pers,its]))

for iters in range(its):
    hist = np.zeros([pers,nDims])
    e_hist = np.zeros([pers,1])
    i_hist = np.zeros([pers,1])
    j_hist = np.zeros([pers,1])
    
    RE_hist = np.zeros([pers,1])
    pi_tilde_hist = []
    for ite in range(len(π̃_norm_)):
        pi_tilde_hist.append(np.zeros([pers,1]))
    
    hist[0,:] = [R_0, K_0, F_0, K_0]
    e_hist[0] = e_func(hist[0,:]) * hist[0,0]
    i_hist[0] = i_func(hist[0,:]) * hist[0,1]
    j_hist[0] = j_func(hist[0,:]) * hist[0,0]
    RE_hist[0] = RE_func(hist[0,:])
    
    for ite in range(len(π̃_norm_)):
        pi_tilde_hist[ite][0] = π̃_norm_func[ite](hist[0,:])
    
    for tm in range(1,pers):
        shock = norm.rvs(0,np.sqrt(dt),nDims)
        hist[tm,0] = cap(hist[tm-1,0] * np.exp((muR(hist[tm-1,:])- 0.5 * sum((sigmaR(hist[tm-1,:])) ** 2))* dt + sigmaR(hist[tm-1,:]).dot(shock)),lowerbounds[0], upperbounds[0])
#         hist[tm,1] = cap(hist[tm-1,1] * np.exp((muK_tilted(hist[tm-1,:])- 0.5 * sum((sigmaK(hist[tm-1,:])) ** 2))* dt + sigmaK(hist[tm-1,:]).dot(shock)),lowerbounds[1], upperbounds[1])
        hist[tm,1] = cap(hist[tm-1,1] * np.exp((muK_base(hist[tm-1,:])- 0.5 * sum((sigmaK(hist[tm-1,:])) ** 2))* dt + sigmaK(hist[tm-1,:]).dot(shock)),lowerbounds[1], upperbounds[1])
        hist[tm,2] = cap(hist[tm-1,2] + muF(hist[tm-1,:]) * dt + sigmaF(hist[tm-1,:]).dot(shock), lowerbounds[2], upperbounds[2])
#         hist[tm,3] = cap(hist[tm-1,3] * np.exp((muK_base(hist[tm-1,:])- 0.5 * sum((sigmaK(hist[tm-1,:])) ** 2))* dt + sigmaK(hist[tm-1,:]).dot(shock)),lowerbounds[3], upperbounds[3])
        hist[tm,3] = cap(hist[tm-1,3] * np.exp((muK_tilted(hist[tm-1,:])- 0.5 * sum((sigmaK(hist[tm-1,:])) ** 2))* dt + sigmaK(hist[tm-1,:]).dot(shock)),lowerbounds[3], upperbounds[3])

        e_hist[tm] = e_func(hist[tm-1,:]) * hist[tm-1,0]
        i_hist[tm] = i_func(hist[tm-1,:]) * hist[tm-1,1]
#         j_hist[tm] = j_func(hist[tm-1,:]) * hist[tm-1,0]
        j_hist[tm] = j_func(hist[tm-1,:]) * hist[tm-1,1]
        RE_hist[tm] = RE_func(hist[tm-1, :])
        
        for ite in range(len(π̃_norm_)):
            pi_tilde_hist[ite][tm] = π̃_norm_func[ite](hist[tm-1,:])

    hists[:,:,iters] = hist
    e_hists[:,[iters]] = e_hist
    i_hists[:,[iters]] = i_hist
    j_hists[:,[iters]] = j_hist
    
    RE_hists[:,[iters]] =  RE_hist
    
    for ite in range(len(π̃_norm_)):
        pi_tilde_hists[ite][:,[iters]] = pi_tilde_hist[ite]

# %%
for_check = loadmat('/Users/han/Dropbox/share with John/Final Code/Growth_JY_Final/HJB_Growth_Averse_Sims_JY.mat')
# for_check = loadmat('/Users/han/Dropbox/share with John/Final Code/Growth_JY_Final/HJB_Growth_Neutral_Sims_JY.mat')

# %%
import matplotlib.pyplot as plt
# plt.plot(for_check['hists2'][:,0])
# plt.plot(hists[:,0,0])

# plt.plot(for_check['f_hists2'])
# plt.plot(j_hist)
# np.max(np.abs(j_hist-for_check['f_hists2']))

np.max(np.abs(j - for_check['f']))
np.mean(np.abs(j))

for_check['hists2'][:,0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-41c434179eef> in <module>
#       7 # np.max(np.abs(j_hist-for_check['f_hists2']))
#       8
# ----> 9 np.max(np.abs(j - for_check['f']))
#      10 np.mean(np.abs(j))
#      11
#
# NameError: name 'np' is not defined

# %% [markdown]
# ### SCC Calculation Feyman Kac

# %% [markdown]
# The growth damages model setting is solved using the same numerical method as the preference damage model, with a few minor adjustments made to the equations and calculations. First, the expressions for $\Psi^*(x)$ and $\bar{\Psi}(x)$ are now given by
#
# \begin{align*}
#  \Psi^*(x) & = -  \int_{\Theta} V_k(x) \left[ \nabla \Gamma(\beta f) \beta \right] q^*(\theta | x) P(d\theta) \\
#  \bar{\Psi}(x) & = -  \int_{\Theta} V_k(x) \left[ \nabla \Gamma(\beta f) \beta \right] P(d\theta).
# \end{align*}
#
# Second, these integral expressions can be calculated using entirely analytical simplifictions as will be outlined below.
#
# Finally, there are no longer direct contributions to the damage evolution that have integral expressions that need to be numerically calculated and added to the PDEs derived from application of the F-K formula.
#
# With these differences we can apply the analogous approach to the preference damage setting to derive $ecc^*$, $\bar{ecc}$, and $ucc^*$ for the growth damages model setting. As before, after imposing the same finite difference scheme the PDEs are characterized by unconditionally linear equations that we can solve directly by approximately inverting the linear systems using the conjugate gradient method without the use of the false transient or other iterative schemes. These PDEs can also be alternatively be solved using the implicit, finite-difference scheme with the conjugate gradient solver augmented by a false transient where the coefficients are definied as in the preference damage case, appropriately adjusted for the $\mu^*_X[x,a^*(x)]$, $\mu_X[x,a^*(x)]$, $\Psi^*(x)$, and $\bar{\Psi}(x)$ that correspond to the growth damages model.

# %%
base_ = loadmat('/Users/han/Dropbox/share with John/Final Code/Growth_JY_Final/SCC_mat_Cumu_base_GrowthAmb_1e9.mat')
# base_ = loadmat('/Users/han/Dropbox/share with John/Final Code/Growth_JY_Final/SCC_mat_Cumu_base_GrowthNoAmb_1e9.mat')
base_guess = base_['v0']

worst_ = loadmat('/Users/han/Dropbox/share with John/Final Code/Growth_JY_Final/SCC_mat_Cumu_worst_GrowthAmb_1e9.mat')
# base_ = loadmat('/Users/han/Dropbox/share with John/Final Code/Growth_JY_Final/SCC_mat_Cumu_base_GrowthNoAmb_1e9.mat')
worst_guess = worst_['v0']

# %%
a, b, c, dmg_ = ([] for ite in range(4)) 
for ite in range(len(π̃_norm_)):
    a.append(np.zeros(F_mat.shape) )
    b.append(v0_dk * (gamma1[ite] + gamma2[ite] * F̄))
    c.append(2 * v0_dk * gamma2[ite] * F_mat)
    dmg_.append(a[ite] + b[ite] * βf + 0.5 * c[ite] * βf ** 2 + 0.5 * c[ite] / λ)
    
flow_base = sum(w * d for w, d in zip(weight, dmg_))

a, b, c, dmg_ = ([] for ite in range(4)) 
for ite in range(len(π̃_norm_)):
    a.append(v0_dk * (gamma0[ite] + gamma1[ite] * F̄ + 0.5 * gamma2[ite] * F̄ ** 2))
    b.append(v0_dk * F_mat * (gamma1[ite] + gamma2[ite] * F̄))
    c.append(v0_dk * gamma2[ite] * F_mat ** 2)
    dmg_.append(a[ite] + b[ite] * βf + 0.5 * c[ite] * βf ** 2 + 0.5 * c[ite] / λ)

Gamma_base = sum(w * d for w, d in zip(weight, dmg_))

A = -δ * np.ones(R_mat.shape)
# B_r = -e + ψ0 * (j ** ψ1) - 0.5 * (σ𝘳 ** 2)
B_r = -e + ψ0 * (j ** ψ1) * np.exp(ψ1 * (K_mat - R_mat)) - 0.5 * (σ𝘳 ** 2)
B_k = μ̄ₖ + ϕ0 * np.log(1 + i * ϕ1) - 0.5 * (σ𝘬 ** 2) - Gamma_base
B_f = e * np.exp(R_mat)
C_rr = 0.5 * σ𝘳 ** 2 * np.ones(R_mat.shape)
C_kk = 0.5 * σ𝘬 ** 2 * np.ones(R_mat.shape)
C_ff = np.zeros(R_mat.shape)
D = flow_base

# out = PDESolver(stateSpace, A, B_r, B_f, B_k, C_rr, C_ff, C_kk, D, v0, ε, 'Feyman Kac')
out = PDESolver(stateSpace, A, B_r, B_f, B_k, C_rr, C_ff, C_kk, D, base_guess, ε, 'Feyman Kac')
v0_base = out[2].reshape(v0.shape, order="F")
v0_base = v0_base

v0_dr_base = finiteDiff(v0_base,0,1,hR,1e-16) 
v0_df_base = finiteDiff(v0_base,1,1,hF)
v0_dk_base = finiteDiff(v0_base,2,1,hK)

v0_drr_base = finiteDiff(v0_base,0,2,hR)
v0_dff_base = finiteDiff(v0_base,1,2,hF)
v0_dkk_base = finiteDiff(v0_base,2,2,hK)


PDE_rhs = A * v0_base + B_r * v0_dr_base + B_f * v0_df_base + B_k * v0_dk_base + C_rr * v0_drr_base + C_kk * v0_dkk_base + C_ff * v0_dff_base + D
PDE_Err = np.max(abs(PDE_rhs))
print("Feyman Kac Base Model Solved. PDE Error: {:.10f}; Iterations: {:d}; CG Error: {:.10f}".format(PDE_Err, out[0], out[1]))

a, b, c, dmg_tilt_ = ([] for ite in range(4)) 
for ite in range(len(π̃_norm_)):
    a.append(np.zeros(F_mat.shape) )
    b.append(v0_dk * (gamma1[ite] + gamma2[ite] * F̄))
    c.append(2 * v0_dk * gamma2[ite] * F_mat)
    dmg_tilt_.append(a[ite] + b[ite] * β̃_[ite] + 0.5 * c[ite] * β̃_[ite] ** 2 + 0.5 * c[ite] / λ̃_[ite])
    
flow_tilted = sum(w * d for w, d in zip(π̃_norm_, dmg_tilt_))

a, b, c, dmg_tilt_ = ([] for ite in range(4)) 
for ite in range(len(π̃_norm_)):
    a.append(v0_dk * (gamma0[ite] + gamma1[ite] * F̄ + 0.5 * gamma2[ite] * F̄ ** 2))
    b.append(v0_dk * F_mat * (gamma1[ite] + gamma2[ite] * F̄))
    c.append(v0_dk * gamma2[ite] * F_mat ** 2)
    dmg_tilt_.append(a[ite] + b[ite] * β̃_[ite] + 0.5 * c[ite] * β̃_[ite] ** 2 + 0.5 * c[ite] / λ̃_[ite])

Gamma_tilted = sum(w * d for w, d in zip(π̃_norm_, dmg_tilt_))

A = -δ * np.ones(R_mat.shape)
# B_r = -e + ψ0 * (j ** ψ1) - 0.5 * (σ𝘳 ** 2)
B_r = -e + ψ0 * (j ** ψ1) * np.exp(ψ1 * (K_mat - R_mat)) - 0.5 * (σ𝘳 ** 2)
B_k = μ̄ₖ + ϕ0 * np.log(1 + i * ϕ1) - 0.5 * (σ𝘬 ** 2) - Gamma_tilted
B_f = e * np.exp(R_mat)
C_rr = 0.5 * σ𝘳 ** 2 * np.ones(R_mat.shape)
C_kk = 0.5 * σ𝘬 ** 2 * np.ones(R_mat.shape)
C_ff = np.zeros(R_mat.shape)
D = flow_tilted


# out = PDESolver(stateSpace, A, B_r, B_f, B_k, C_rr, C_ff, C_kk, D, v0, ε, 'Feyman Kac')
out = PDESolver(stateSpace, A, B_r, B_f, B_k, C_rr, C_ff, C_kk, D, worst_guess, ε, 'Feyman Kac')
v0_worst = out[2].reshape(v0.shape, order="F")
v0_worst = v0_worst

v0_dr_worst = finiteDiff(v0_worst,0,1,hR,1e-16) 
v0_df_worst = finiteDiff(v0_worst,1,1,hF)
v0_dk_worst = finiteDiff(v0_worst,2,1,hK)

v0_drr_worst = finiteDiff(v0_worst,0,2,hR)
v0_dff_worst = finiteDiff(v0_worst,1,2,hF)
v0_dkk_worst = finiteDiff(v0_worst,2,2,hK)

PDE_rhs = A * v0_worst + B_r * v0_dr_worst + B_f * v0_df_worst + B_k * v0_dk_worst + C_rr * v0_drr_worst + C_kk * v0_dkk_worst + C_ff * v0_dff_worst + D
PDE_Err = np.max(abs(PDE_rhs))
print("Feyman Kac Worst Model Solved. PDE Error: {:.10f}; Iterations: {:d}; CG Error: {:.10f}".format(PDE_Err, out[0], out[1]))
# Out:
# Feyman Kac Base Model Solved. PDE Error: 0.0000271175; Iterations: 10; CG Error: 0.0278141790
# Feyman Kac Worst Model Solved. PDE Error: 0.0000561943; Iterations: 10; CG Error: 0.0287456823

# %%
# JY = worst_['f']**worst_['']
# AW = ψ0 * (j ** ψ1)
np.max(np.abs(worst_['r_mat'] - R_mat))
# np.mean(np.abs(j))

np.max(np.abs(worst_['f']-j))

np.mean(np.abs(B_r - worst_['B_r']))
# Out:
# 0.00029944533687765686

# %%
# time_vec = np.linspace(0,100,400)

# MC = δ * (1-κ) / (α * np.exp(K_mat) - i * np.exp(K_mat) - j * np.exp(R_mat))
MC = δ * (1-κ) / (α * np.exp(K_mat) - i * np.exp(K_mat) - j * np.exp(K_mat))
ME = δ * κ / (e * np.exp(R_mat))
SCC = 1000 * ME / MC
SCC_func_r = GridInterp(gridpoints, SCC, method)

def SCC_func(x): 
#     return SCC_func_r.get_value(np.log(x[0]), x[2], np.log(x[3]))
    return SCC_func_r.get_value(np.log(x[0]), x[2], np.log(x[1]))

ME1 = v0_dr * np.exp(-R_mat)
SCC1 = 1000 * ME1 / MC
SCC1_func_r = GridInterp(gridpoints, SCC1, method)
def SCC1_func(x):
#     return SCC1_func_r.get_value(np.log(x[0]), x[2], np.log(x[3]))
    return SCC1_func_r.get_value(np.log(x[0]), x[2], np.log(x[1]))


ME2_base = v0_base
SCC2_base = 1000 * ME2_base / MC
SCC2_base_func_r = GridInterp(gridpoints, SCC2_base, method)
def SCC2_base_func(x):
#     return SCC2_base_func_r.get_value(np.log(x[0]), x[2], np.log(x[3]))
    return SCC2_base_func_r.get_value(np.log(x[0]), x[2], np.log(x[1]))


ME2_base_a = -v0_df
SCC2_base_a = 1000 * ME2_base_a / MC
SCC2_base_a_func_r = GridInterp(gridpoints, SCC2_base_a, method)
def SCC2_base_a_func(x):
#     return SCC2_base_a_func_r.get_value(np.log(x[0]), x[2], np.log(x[3]))
    return SCC2_base_a_func_r.get_value(np.log(x[0]), x[2], np.log(x[1]))


ME2_tilt = v0_worst
SCC2_tilt = 1000 * ME2_tilt / MC
SCC2_tilt_func_r = GridInterp(gridpoints, SCC2_tilt, method)
def SCC2_tilt_func(x):
#     return SCC2_tilt_func_r.get_value(np.log(x[0]), x[2], np.log(x[3]))
    return SCC2_tilt_func_r.get_value(np.log(x[0]), x[2], np.log(x[1]))


SCC_values = np.zeros([pers,its])
SCC1_values = np.zeros([pers,its])
SCC2_base_values = np.zeros([pers,its])
SCC2_tilt_values = np.zeros([pers,its])
SCC2_base_a_values = np.zeros([pers,its])

for tm in range(pers):
    for path in range(its):   
        SCC_values[tm, path] = SCC_func(hists[tm,:,path])
        SCC1_values[tm, path] = SCC1_func(hists[tm,:,path])
        SCC2_base_values[tm, path] = SCC2_base_func(hists[tm,:,path]) 
        SCC2_tilt_values[tm, path] = SCC2_tilt_func(hists[tm,:,path])
        SCC2_base_a_values[tm, path] = SCC2_base_a_func(hists[tm,:,path])
        
SCC_total = np.mean(SCC_values,axis = 1)
SCC_private = np.mean(SCC1_values,axis = 1)
SCC2_FK_base = np.mean(SCC2_base_values,axis = 1)
SCC2_FK_tilt = np.mean(SCC2_tilt_values,axis = 1)

uncertain = SCC2_FK_tilt - SCC2_FK_base

uncertain = SCC2_FK_tilt - SCC2_FK_base

SCCs = {}
SCCs['SCC'] = SCC_total
SCCs['SCC1'] = SCC_private
SCCs['SCC2'] = SCC2_FK_base
SCCs['SCC3'] = SCC2_FK_tilt - SCC2_FK_base

# %%
for_check = loadmat('/Users/han/Dropbox/share with John/Final Code/Growth_JY_Final/for_check.mat')

# %%
import matplotlib.pyplot as plt
plt.plot(np.squeeze(for_check['SCC2_FK_base']))
plt.plot(SCC2_FK_base)

# %% [markdown]
# ### Probabilities

# %%
Dists = {}

a = β𝘧 - 5 * np.sqrt(σᵦ)
b = β𝘧 + 5 * np.sqrt(σᵦ)
a_10std = β𝘧 - 10 * np.sqrt(σᵦ)
b_10std = β𝘧 + 10 * np.sqrt(σᵦ)
beta_f_space = np.linspace(a_10std,b_10std,200)

original_dist = norm.pdf(beta_f_space, β𝘧, np.sqrt(σᵦ))
Dists['Original'] = original_dist

R_value = np.mean(hists[:,0,:], axis = 1)
K_value = np.mean(hists[:,1,:], axis = 1)
F_value = np.mean(hists[:,2,:], axis = 1)

R_func_r = []
R_func = []
β̃_func_r = []
β̃_func = []
λ̃_func_r = []
λ̃_func = []
for ite in range(len(R_)):
    R_func_r.append(GridInterp(gridpoints, R_[ite], method))
    R_func.append(lambda x, ite = ite: R_func_r[ite].get_value(np.log(x[0]), x[2], np.log(x[1])))
    β̃_func_r.append(GridInterp(gridpoints, β̃_[ite], method))
    β̃_func.append(lambda x, ite = ite: β̃_func_r[ite].get_value(np.log(x[0]), x[2], np.log(x[1])))
    λ̃_func_r.append(GridInterp(gridpoints, λ̃_[ite], method))
    λ̃_func.append(lambda x, ite = ite: λ̃_func_r[ite].get_value(np.log(x[0]), x[2], np.log(x[1])))

hists_mean = np.mean(hists, axis = 2)
RE_plot = np.zeros(pers)
weight_plot = [np.zeros([pers,1]) for ite in range(len(π̃_norm_func))]
for tm in range(pers):
    RE_plot[tm] = RE_func(hists_mean[tm,:])
    for ite in range(len(π̃_norm_func)):
        weight_plot[ite][tm] = π̃_norm_func[ite](hists_mean[tm,:])

for tm in [1,100,200,300,400]:
    R0 = hists[tm-1,0,0]
    K0 = hists[tm-1,1,0]
    F0 = hists[tm-1,2,0]
    weights_prob = []
    mean_distort_ = []
    lambda_tilde_ = []
    tilt_dist_ = []
    
    for ite in range(len(π̃_norm_func)):
        weights_prob.append(π̃_norm_func[ite]([R0, K0, F0]))
        mean_distort_.append(β̃_func[ite]([R0, K0, F0]) - βf)
        lambda_tilde_.append(λ̃_func[ite]([R0, K0, F0]))
        tilt_dist_.append(norm.pdf(beta_f_space, mean_distort_[ite] + βf, 1 / np.sqrt(lambda_tilde_[ite])))
        
    weighted = sum(w * til for w, til in zip(weights_prob, tilt_dist_) )
    Dists['Year' + str(int((tm) / 4))] = dict(tilt_dist = tilt_dist_, weighted = weighted, weights = weights_prob)

# %%
for_check = loadmat('./MATLAB_Data/Dist_50yr.mat')
np.max(abs(for_check['weighted'] - Dists['Year50']['weighted']))

# %%
Dists['Year100']['weighted']

# %%
max([1,2,3,4,5,6,7]) < 5

# %%
np.c_[for_check['RE_plot'][0], RE_plot]
